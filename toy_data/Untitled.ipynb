# %%
import pandas as pd

df = pd.read_csv('train_onehot.csv')

# %%
df_ = df.fillna(df.median())

# %%
df_
# Out:
#        continuous_f0024  continuous_f0080  continuous_f0087  continuous_f0101  \
# 0                  10.0               1.0          0.002000          0.824859
# 1                  10.0               1.0          0.001000          0.221901
# 2                  10.0               1.0          0.010000          0.221901
# 3                  10.0               1.0          0.002000          0.221901
# 4                  10.0               1.0          0.002000          0.448679
# ...                 ...               ...               ...               ...
# 99995              10.0               1.0          0.002000          0.140196
# 99996              10.0               1.0          0.002000          0.221901
# 99997              10.0               1.0          0.020000          0.221901
# 99998              10.0               1.0          0.002000          0.060241
# 99999              10.0               1.0          0.000199          0.221901
#
# ...
